# %% [markdown]
# <center><b><font color='blue', size=5>BIKERS' NATION ANALYTICS</font></b></center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Bikes = pd.read_excel('bikes.xlsx')

# %%
Bikes
# Out:
#        Transaction ID Transaction Date  ONLine OrdeR Order Status  \
# 0                   1       2017-02-25             0     Approved
# 1                   2       2017-05-21             1     Approved
# 2                   3       2017-10-16             0     Approved
# 3                   4       2017-08-31             0     Approved
# 4                   5       2017-10-01             1     Approved
# ...               ...              ...           ...          ...
# 19995           19996       2017-06-24             1     Approved
# 19996           19997       2017-11-09             1     Approved
# 19997           19998       2017-04-14             1     Approved
# 19998           19999       2017-07-03             0     Approved
# 19999           20000       2017-09-22             1     Approved
#
#                 BRAND Product LINE PRODUCT CLAss product_size  selling price  \
# 0               Solex     Standard        medium       medium             71
# ...

# %%
Bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    20000 non-null  int64
#  1   Transaction Date  20000 non-null  datetime64[ns]
#  2   ONLine OrdeR      19640 non-null  float64
#  3   Order Status      20000 non-null  object
#  4   BRAND             19803 non-null  object
#  5   Product LINE      19803 non-null  object
#  6   PRODUCT CLAss     19803 non-null  object
#  7   product_size      19803 non-null  object
#  8   selling price     20000 non-null  float64
#  9   StanDARD COST     19803 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 1.5+ MB

# %%
Bikes.columns=Bikes.columns.str.lower()

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709

# %%
#checking the percentage of null values in the dataframe
Bikes.isnull().sum()/len(Bikes)*100
# Out:
# transaction id     0
# transaction date   0
# online order       2
# order status       0
# brand              1
# product line       1
# product class      1
# product_size       1
# selling price      0
# standard cost      1
# dtype: float64

# %% [markdown]
# if the perentage of null values are less than 5%, and we couldn't find a value for replacement, it's advisable to drop the rows with the null values

# %%
Bikes.describe(include=[object])
# Out:
#        order status  brand product line product class product_size
# count         20000  19803        19803         19803        19803
# unique            2      6            4             3            3
# top        Approved  Solex     Standard        medium       medium
# freq          19821   4253        14176         13826        12990

# %%
Bikes['online order'].isnull().sum()
# Out:
# 360

# %%
Bikes['online order'].fillna(Bikes['online order'].mean(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_26500\3569025342.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Bikes['online order'].fillna(Bikes['online order'].mean(),inplace=True)

# %%
Bikes['online order'].isnull().sum()
# Out:
# 0

# %%
Bikes.isnull().sum()/len(Bikes)*100
# Out:
# transaction id     0
# transaction date   0
# online order       0
# order status       0
# brand              1
# product line       1
# product class      1
# product_size       1
# selling price      0
# standard cost      1
# dtype: float64

# %%
Bikes.columns.dropna()
# Out:
# Index(['transaction id', 'transaction date', 'online order', 'order status',
#        'brand', 'product line', 'product class', 'product_size',
#        'selling price', 'standard cost'],
#       dtype='object')

# %%
Bikes.dropna(axis=0, inplace=True)

# %%
Bikes.isnull().sum()
# Out:
# transaction id      0
# transaction date    0
# online order        0
# order status        0
# brand               0
# product line        0
# product class       0
# product_size        0
# selling price       0
# standard cost       0
# dtype: int64

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709

# %%
Bikes['profit'] = Bikes['selling price'] - Bikes['standard cost']

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost  \
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709
#
#    profit
# 0      18
# 1   1,703
# 2   1,545
# 3     817
# ...

# %%
Bikes['month'] = Bikes['transaction date'].dt.month

# %%
Bikes['month'].sort_values(ascending=True)
# Out:
# 11282     1
# 3698      1
# 3702      1
# 3705      1
# 8704      1
#          ..
# 5505     12
# 11134    12
# 7132     12
# 3333     12
# 850      12
# Name: month, Length: 19803, dtype: int32

# %%
Bikes['transaction date'] =pd.to_datetime(Bikes['transaction date'])

# %%
Bikes['transaction date'].dt.strftime('%d-%b-%y') #convert the date to the day-month-year format
# Out:
# 0        25-Feb-17
# 1        21-May-17
# 2        16-Oct-17
# 3        31-Aug-17
# 4        01-Oct-17
#            ...
# 19995    24-Jun-17
# 19996    09-Nov-17
# 19997    14-Apr-17
# 19998    03-Jul-17
# 19999    22-Sep-17
# Name: transaction date, Length: 19803, dtype: object

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost  \
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709
#
#    profit  month
# 0      18      2
# 1   1,703      5
# ...

# %% [markdown]
# ### Product Size

# %%
Bikes['product_size'].unique()
# Out:
# array(['medium', 'large', 'small'], dtype=object)

# %%
Bikes['product_size'].value_counts(normalize=True)*100
# Out:
# product_size
# medium   66
# large    20
# small    14
# Name: proportion, dtype: float64

# %%
product_size = Bikes['product_size'].value_counts(normalize=True)*100

# %%
product_size.index # get the index of the product size
# Out:
# Index(['medium', 'large', 'small'], dtype='object', name='product_size')

# %%
product_size.values
# Out:
# array([65.5961218 , 20.077766  , 14.32611221])

# %%
#plotting a pie chart
plt.pie(product_size, labels=product_size.index, autopct='%1.2f%%')
plt.title('Distribution of Product Size');

# %%
#product size profit
product_size_proft = Bikes.groupby('product_size')['profit'].sum().sort_values()
product_size_proft
# Out:
# product_size
# small      403,081
# large    3,646,175
# medium   6,881,028
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(product_size_proft.index, product_size_proft, color='gold')

# list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_size_proft], padding=3)
plt.title('Profit Distribution by Product Size')
plt.xticks(ticks=[])
plt.show()

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost  \
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709
#
#    profit  month
# 0      18      2
# 1   1,703      5
# ...

# %% [markdown]
# ## Brand

# %%
# frequency of brand
brand_frequency = round(Bikes['brand'].value_counts(normalize=True)*100,2)

# %%
brand_frequency
# Out:
# brand
# Solex            21
# Giant Bicycles   17
# WeareA2B         17
# OHM Cycles       15
# Trek Bicycles    15
# Norco Bicycles   15
# Name: proportion, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(brand_frequency.index, brand_frequency, color='gray')

#list comprehension, formatting
ax.bar_label(bars, label= [f'{value:,.0f}' for value in brand_frequency], padding=4)
plt.title('Distribution of Brand Purchase')
plt.yticks(ticks=[])
plt.show()

# %%
#It ensures that the values are displayed in whole
pd.set_option('display.float_format','{:,.0f}'.format)

# %%
# Brand Profitability
Bikes.groupby('brand')['profit'].sum().sort_values(ascending=False)
# Out:
# brand
# WeareA2B         2,753,895
# Solex            2,413,852
# Trek Bicycles    1,837,974
# Giant Bicycles   1,573,840
# OHM Cycles       1,483,039
# Norco Bicycles     867,684
# Name: profit, dtype: float64

# %%
brands_profit = Bikes.groupby('brand')['profit'].sum().sort_values(ascending=False)
brands_profit
# Out:
# brand
# WeareA2B         2,753,895
# Solex            2,413,852
# Trek Bicycles    1,837,974
# Giant Bicycles   1,573,840
# OHM Cycles       1,483,039
# Norco Bicycles     867,684
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(brands_profit.index, brands_profit, color='gray')

#list comprehesion, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in brands_profit], padding=4)
plt.title('Profit by Brand')
plt.yticks(ticks=[])
plt.show()

# %% [markdown]
# ### Product Line

# %%
Bikes['product line'].value_counts()
# Out:
# product line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64

# %%
Product_line_frequency = (Bikes['product line'].value_counts(normalize=True)*100).sort_values(ascending=True)
Product_line_frequency
# Out:
# product line
# Mountain    2
# Touring     6
# Road       20
# Standard   72
# Name: proportion, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(Product_line_frequency.index, Product_line_frequency, color='navy')

#list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in Product_line_frequency], padding=3)
plt.title('Distribution of Product line Purchase')
plt.xticks(ticks=[])
plt.show()

# %%
Bikes.groupby('product line')['profit'].sum().sort_values(ascending=False)
# Out:
# product line
# Standard   8,138,950
# Road       1,400,397
# Touring    1,350,158
# Mountain      40,779
# Name: profit, dtype: float64

# %%
product_line_profit = Bikes.groupby('product line')['profit'].sum().sort_values(ascending=False)
product_line_profit
# Out:
# product line
# Standard   8,138,950
# Road       1,400,397
# Touring    1,350,158
# Mountain      40,779
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(product_line_profit.index, product_line_profit, color='navy')

# list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_line_profit], padding= 3)
plt.title('Profit by Product Line')
plt.yticks(ticks=[])
plt.show()

# %% [markdown]
# ### Product Class

# %%
Bikes['product class'].value_counts(normalize=True)*100
# Out:
# product class
# medium   70
# high     15
# low      15
# Name: proportion, dtype: float64

# %%
product_class_frequency = (Bikes['product class'].value_counts(normalize=True)*100).sort_values(ascending=True)
product_class_frequency
# Out:
# product class
# low      15
# high     15
# medium   70
# Name: proportion, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(product_class_frequency.index, product_class_frequency, color='maroon')

#list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_class_frequency], padding=3)
plt.title('Distribution of Product Class Purchase')
plt.xticks(ticks=[])
plt.show()

# %%
product_class_profit = Bikes.groupby('product class')['profit'].sum()
product_class_profit
# Out:
# product class
# high     1,115,726
# low      1,204,528
# medium   8,610,031
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(product_class_profit.index, product_class_profit, color='maroon')

# list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_class_profit], padding=3)
plt.title('Profit by Product Class')
plt.xticks(ticks=[])
plt.show()

# %% [markdown]
# ### Product Size

# %%
product_size_frequency = Bikes['product_size'].value_counts(normalize=True)*100
product_size_frequency
# Out:
# product_size
# medium   66
# large    20
# small    14
# Name: proportion, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(product_size_frequency.index, product_size_frequency, color='olive')

# list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_size_frequency], padding=3)
plt.title('Distribution of Product Size Purchase')
plt.yticks(ticks=[])
plt.show()

# %%
product_size_profit = Bikes.groupby('product_size')['profit'].sum().sort_values()
product_size_profit
# Out:
# product_size
# small      403,081
# large    3,646,175
# medium   6,881,028
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(product_size_profit.index, product_size_profit, color='olive')

# list comprehension, formatting
ax.bar_label(bars, [f'{value:,.0f}' for value in product_size_profit], padding=3)
plt.title('Profit by Product Size')
plt.xticks(ticks=[])
plt.show()

# %% [markdown]
# ### Monthly Purchase

# %%
frequency_of_monthly_purchase = Bikes['month'].value_counts().sort_index()
frequency_of_monthly_purchase
# Out:
# month
# 1     1665
# 2     1612
# 3     1629
# 4     1641
# 5     1666
# 6     1564
# 7     1700
# 8     1735
# 9     1559
# 10    1751
# 11    1648
# 12    1633
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5), dpi=100)
plt.plot(frequency_of_monthly_purchase.index, frequency_of_monthly_purchase, marker='o', markersize=6, ls='--', lw=1, mfc='blue', color='hotpink')
plt.title('Distribution of Monthly Purchase')
plt.show()

# %%
monthly_profit = Bikes.groupby('month')['profit'].sum().sort_index()
monthly_profit
# Out:
# month
# 1    929,488
# 2    870,819
# 3    879,243
# 4    904,691
# 5    913,743
# 6    859,572
# 7    938,619
# 8    970,453
# 9    862,290
# 10   984,973
# 11   924,938
# 12   891,454
# Name: profit, dtype: float64

# %%
plt.figure(figsize=(10,5), dpi=100)
plt.plot(monthly_profit.index, monthly_profit, ls='--', lw=1, markersize=6, marker='o', mfc='blue', color='hotpink')
plt.title('Profit by Monthly Purchase')
plt.show()

# %%
Bikes.head()
# Out:
#    transaction id transaction date  online order order status           brand  \
# 0               1       2017-02-25             0     Approved           Solex
# 1               2       2017-05-21             1     Approved   Trek Bicycles
# 2               3       2017-10-16             0     Approved      OHM Cycles
# 3               4       2017-08-31             0     Approved  Norco Bicycles
# 4               5       2017-10-01             1     Approved  Giant Bicycles
#
#   product line product class product_size  selling price  standard cost  \
# 0     Standard        medium       medium             71             54
# 1     Standard        medium        large          2,091            389
# 2     Standard           low       medium          1,793            249
# 3     Standard        medium       medium          1,198            381
# 4     Standard        medium        large          1,765            709
#
#    profit  month
# 0      18      2
# 1   1,703      5
# ...

# %% [markdown]
# ### Order Status

# %%
#Frequency distribution of order status
order_status_frequency = Bikes['order status'].value_counts().sort_values(ascending=False)
order_status_frequency
# Out:
# order status
# Approved     19625
# Cancelled      178
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(order_status_frequency.index, order_status_frequency, color='pink')

ax.bar_label(bars, [f'{value:,.0f}' for value in order_status_frequency], padding=3)
plt.title('Frequency Distribution of Order Status')
plt.yticks(ticks=[])
plt.show()

# %%
#Profit Distribution of order status
order_status_profit = Bikes.groupby('order status')['profit'].sum().sort_values()
order_status_profit
# Out:
# order status
# Cancelled       98,780
# Approved    10,831,504
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.barh(order_status_profit.index, order_status_profit, color='pink')

ax.bar_label(bars, [f'{value:,.0f}' for value in order_status_profit], padding=3)
plt.title('Profit Distribution by Order Status')
plt.xticks(ticks=[])
plt.show()

# %% [markdown]
# ### Online Order

# %%
order_map = {1: 'Yes', 0: 'No'}
Bikes['online order'] = Bikes['online order'].map(order_map)

# %%
online_or_offline_order = Bikes['online order'].value_counts()
online_or_offline_order
# Out:
# online order
# Yes    9739
# No     9706
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(online_or_offline_order.index, online_or_offline_order, color='silver')

ax.bar_label(bars, [f'{value:,.0f}' for value in online_or_offline_order], padding=3)
plt.title('Frequency Distribution of Online Vs Offline Orders')
plt.yticks(ticks=[])
plt.show()

# %%
#Profit Distribution of Online Vs Offline Orders
Bikes.groupby('online order')['profit'].sum()
# Out:
# online order
# No    5,387,900
# Yes   5,340,917
# Name: profit, dtype: float64

# %%
online_offline_profit = Bikes.groupby('online order')['profit'].sum()
online_offline_profit
# Out:
# online order
# No    5,387,900
# Yes   5,340,917
# Name: profit, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5))
bars = ax.bar(online_offline_profit.index, online_offline_profit, color='silver')

ax.bar_label(bars, [f'{value:,.0f}' for value in online_offline_profit], padding=3)
plt.title('Profit by Online Vs Offline Orders')
plt.yticks(ticks=[])
plt.show()

# %% [markdown]
# <!-- <h1><center><b><font color='navy'>BIKERS' NATION DASHBOARD</b></center></h1>
# -->

# %% [markdown]
# ## Dashboard

# %%
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(20,20))
fig.suptitle('Bikers\' Nation 2024 Sales Dashboard', fontweight='bold', fontsize=18)

# Product size
#Product size
ax[0,0].pie(product_size, labels=product_size.index, autopct='%1.2f%%')
ax[0,0].set_title('Distribution of Product Size');

# Product size
# Profit by product size
bars = ax[0, 1].barh(product_size_proft.index, product_size_proft, color='navy')

# list comprehension, formatting
ax[0, 1].bar_label(bars, [f'{value:,.0f}' for value in product_size_proft], padding=3)
ax[0, 1].set_title('Profit Distribution by Product Size')
ax[0, 1].set_xticks(ticks=[])

# Brand
#brand frequency
bars = ax[1, 0].bar(brand_frequency.index, brand_frequency, color='navy')

#list comprehension, formatting
ax[1, 0].bar_label(bars, label= [f'{value:,.0f}' for value in brand_frequency], padding=4)
ax[1, 0].set_title('Distribution of Brand Purchase')
ax[1, 0].set_yticks(ticks=[])

# distribution of brand profit
bars = ax[1, 1].bar(brands_profit.index, brands_profit, color='navy')

#list comprehesion, formatting
ax[1, 1].bar_label(bars, [f'{value:,.0f}' for value in brands_profit], padding=4)
ax[1, 1].set_title('Profit by Brand')
ax[1, 1].set_yticks(ticks=[])

# Product Line
#Product line frequency
bars = ax[2, 0].barh(Product_line_frequency.index, Product_line_frequency, color='navy')

#list comprehension, formatting
ax[2, 0].bar_label(bars, [f'{value:,.0f}' for value in Product_line_frequency], padding=3)
ax[2, 0].set_title('Distribution of Product line Purchase')
ax[2, 0].set_xticks(ticks=[])

#product line profit
bars = ax[2, 1].bar(product_line_profit.index, product_line_profit, color='navy')

# list comprehension, formatting
ax[2, 1].bar_label(bars, [f'{value:,.0f}' for value in product_line_profit], padding= 3)
ax[2, 1].set_title('Profit by Product Line')
ax[2, 1].set_yticks(ticks=[])

# Product Class
#product class frequency
bars = ax[3, 0].barh(product_class_frequency.index, product_class_frequency, color='navy')

#list comprehension, formatting
ax[3, 0].bar_label(bars, [f'{value:,.0f}' for value in product_class_frequency], padding=3)
ax[3, 0].set_title('Distribution of Product Class Purchase')
ax[3, 0].set_xticks(ticks=[])

# profit by product class
bars = ax[3, 1].barh(product_class_profit.index, product_class_profit, color='navy')

# list comprehension, formatting
ax[3, 1].bar_label(bars, [f'{value:,.0f}' for value in product_class_profit], padding=3)
ax[3, 1].set_title('Profit by Product Class')
ax[3, 1].set_xticks(ticks=[])

# # Product Size
# # product size frequency
# bars = ax[4, 0].bar(product_size_frequency.index, product_size_frequency, color='navy')

# # list comprehension, formatting
# ax[4, 0].bar_label(bars, [f'{value:,.0f}' for value in product_size_frequency], padding=3)
# ax[4, 0].set_title('Distribution of Product Size Purchase')
# ax[4, 0].set_yticks(ticks=[])

# #profit by product size
# bars = ax[4, 1].barh(product_size_profit.index, product_size_profit, color='navy')

# # list comprehension, formatting
# ax[4, 1].bar_label(bars, [f'{value:,.0f}' for value in product_size_profit], padding=3)
# ax[4, 1].set_title('Profit by Product Size')
# ax[4, 1].set_xticks(ticks=[])

# online_or_offline_order
# online_or_offline_order_frequency
bars = ax[4, 0].bar(online_or_offline_order.index, online_or_offline_order, color='silver')

ax[4, 0].bar_label(bars, [f'{value:,.0f}' for value in online_or_offline_order], padding=3)
ax[4, 0].set_title('Frequency Distribution of Online Vs Offline Orders')
ax[4, 0].set_yticks(ticks=[])

# online_offline_profit
bars = ax[4, 1].bar(online_offline_profit.index, online_offline_profit, color='silver')

ax[4, 1].bar_label(bars, [f'{value:,.0f}' for value in online_offline_profit], padding=3)
ax[4, 1].set_title('Profit by Online Vs Offline Orders')
ax[4, 1].set_yticks(ticks=[])

# Monthly purchase frequency
ax[5, 0].plot(frequency_of_monthly_purchase.index, frequency_of_monthly_purchase, marker='o', markersize=6, ls='--', lw=1, mfc='blue', color='navy')
ax[5, 0].set_title('Distribution of Monthly Purchase')

# Monthly purchase profit
ax[5, 1].plot(monthly_profit.index, monthly_profit, ls='--', lw=1, markersize=6, marker='o', mfc='blue', color='navy')
ax[5, 1].set_title('Profit by Monthly Purchase');

# # online vs offline purchase frequency
# bars = ax[6, 0].bar(online_or_offline_order.index, online_or_offline_order, color='silver')

# ax[6, 0].bar_label(bars, [f'{value:,.0f}' for value in online_or_offline_order], padding=3)
# ax[6, 0].set_title('Frequency Distribution of Online Vs Offline Orders')
# ax[6, 0].set_yticks(ticks=[])

# %% [markdown]
# # Insights

# %% [markdown]
# <h1><center><b><font color='navy'>BIKERS NATION SALES ANALYSIS</font></b></center></h1>

# %% [markdown]
# ### Trend Analysis

# %% [markdown]
# <h5>Distribution of product Size</h5>

# %% [markdown]
# 1. Approximately, <font color='navy'><b>65%</b></font> of the products purchased are medium sized, while about <font color='hotpink'><b>20%</b></font> are large, while small sized products, with <font color='blue'><b>14%</b></font> distribution makes up the least purchased product.
#
# <h5><b>Profit Distribution of Product Size</b></h5>
#
# 2. We observed that medium-sized products have an overall profit of
# <font color='navy'><b>$6.8m</b></font>
#
#   Large products have a profit of <font color='navy'><b>$3.6m</b></font>,
#
# and small-sized products have a profit a little above $400k.
#
# <h5><b>Distribution of Brand Purchase</b></h5>
#
# 3. <b>Solex Brand</b> has the highest percentage distribution or frequency of purchase at approximately <font color='navy'>21%</font>. This is followed by Giant Bicycle brands at <font color='gray'><b></b>16.7</b></font> while WeareA2B garnered <font color='red'>16.6%</font> purchase distribution. Furthermore, <b>CHM Cycles</b> has a total of <font color='navy'>15.4%</font> frequency distribution while <b>Trek Bicycles</b> is closely behind it at <font color='navy'>15%</font>. In addition, <b>Norco Bicycles</b> is the least purchased at <font color='navy'>14.9%</font>. From this, we can deduced that Solex brand is the most patronized of all the brands, and will definitely be the most profitable.
#
# <h5><b>Distribution of Product Line</b></h5>
#
# 4. Amazingly, WeareA2B brand is the most profitable brand having a whopping profit of $2.7m, closely followed by Solex at $2.4m,
#
# Trek Bicycles is at $1.8m, while Giant Bicycles is making over $1.5m in profit, closely followed by CHM bicyles at $1.4m.
#
# The least profitable brand is the Norco Bicycles as predicted, and it's profit is roughly a little bit above $800k.
#
# 7. Standard product line has the highest frequency distribution at 72%, closely followed by Road at 20%, while Touring is behind Road at 6&. Mountain line of products is the least patronized. The frequency distribution of Standard Product is almost three times its closest competitor; thus, we can deduce that Standard line are the most frequently ordered products. Customers also patronize road line of products, but at a low rate compared to the Standard lines.
#
# <h5><b>Profit by Product Line</b></h5>
#
# 6. Standard line of product has an overall profit of $8.1m. This is actually amazing! Road has a little bit above $1.4m, while Touring has qround $1.3m.
#
# Mountain lines is not has profitable, meaning customers seldom purchase mountain products; this shows in the chart as it stuggles to have a profit a little above $40k.
#
# <h5><b>Distribution of Product Class</b></h5>
#
# 7. The product class has to do with the quality of the product. Medium quality products has around 70% patronage, while low quality products has a patronage of a little above 15%; high quality products amazingly has a close range of patronage with high quality products. The insight I got from the data is that, customers often patronize medium or average quality products, possibly because of their purchasing power. Customers often go for what they could afford, regardless of quality, especially if it could meet their needs. Thus, majority of the customers go for medium quality products, while the rich/wealthy customers go for high quality products, while the poor ones go for low quality ones. The range of the purchase between the wealthy and the poor customers is almost the same as shown in the chart.
#
# <h5><b>Profit by Product Class</b></h5>
#
# 8. As we can see from the chart, medium quality products is the most purchased,thus the most profitable; having a little above $8.6m in profit.
#
# This speaks a lot of volume because it shows that the majority of bikers' nation customers prefer to spend their hard-earned money on average quality products than high quality ones. It also tells a lot about the customer distribution of bikers' nation, and their purchasing power. Furthermore, low quality products has a good patronage at a little bit above $1.2m.
#
# While high quality products received the least patronage and profit, having garnered around $1.1m. This shows that, customers prefer an average quality products to high class products; not necessarily because they don't like it, but because they can't afford it! High class products are usually meant for the top 1% of the economic strata; like the millionaires and billionaires, while a 80% of people do not belong to this group.
#
# <h5><b>Frequency Distribution of online Vs offline orders</b></h5>
#
# 9. Around 9,739 orders were online while the offline orders, that is, those that purchased product without using the official website or any other payment channels online were around 9,700 orders; this shows a very close range between online purchases and the traditional means of orders. THis shows that both channels are being actively used for purchases by clients.
#
# <h5><b>Profit Distribution of online Vs offline orders</b></h5>
#
# 10. The cummulative profit made by offline channels is a little bit above $5.387m, while those online is $5.340m. This shows that the traditional means of purchases or orders are more profitable than even the online channels. The bikers' nation need to maximize it's online channels, and utilized it well for optimum profit.
#
# <h5><b>Distribution of monthly purchase</b></h5>
#
# 11. The monthly purchase distribution's behavior is zigzag, as purchases was at its lowest in September, at its peak around October, and later fell in November. This trend needs to be given serious thoughts so as to maximize the peakly months and understand why purchases is always at its lowest in September.
#
# <h5><b>Profit by Monthly Purchase</b></h5>
#
# 12. The profit trend shows that profit generation is at its lowest in September, while at its peak in October. It slighly goes down in November, and later falling a little bit further in December.

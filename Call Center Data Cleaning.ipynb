# %% [markdown]
# <center><b>Call Center Data Cleaning</b></center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_excel(r'C:\Users\HP\Desktop\Splendor Python Class\Customer Call List.xlsx')
df.head(20)
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
df.columns.str.lower()
# Out:
# Index(['customerid', 'first_name', 'last_name', 'phone_number', 'address',
#        'paying customer', 'do_not_contact', 'not_useful_column'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
df2.describe(include=[object])
# Out:
#        First_Name  Last_Name  Phone_Number                      Address  \
# count          21         20            19                           21
# unique         19         19             7                           20
# top        Anakin  Skywalker  876|678|3469  910 Tatooine Road, Tatooine
# freq            2          2             5                            2
#
#        Paying Customer Do_Not_Contact
# count               21             17
# unique               5              4
# top                Yes             No
# freq                11              9

# %%
df2.head()
# df1['last_name'].str.strip('..../')
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df2.columns = df2.columns.str.lower()
df2.head()
# Out:
#    customerid first_name last_name  phone_number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  address paying customer do_not_contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    not_useful_column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
#Cleaning the last_name column by removing the whitespaces and special characters
df2['last_name'] = df2['last_name'].str.strip('.../')
df2['last_name']
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: last_name, dtype: object

# %%
#drop the not useful column
df2 = df2.drop('not_useful_column', axis=1)

# %%
df2.head(20)
# Out:
#     customerid first_name    last_name  phone_number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter        White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry       Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df2[['street address', 'address',  'zip_code']] = df2['address'].str.split(',', expand=True)

# %%
df2.head()
# Out:
#    customerid first_name last_name  phone_number        address  \
# 0        1001      Frodo   Baggins  123-545-5421          Shire
# 1        1002       Abed     Nadir  123/643/9775           None
# 2        1003     Walter     White    7066950392           None
# 3        1004     Dwight   Schrute  123-543-2345   Pennsylvania
# 4        1005        Jon      Snow  876|678|3469           None
#
#   paying customer do_not_contact       street address zip_code
# 0             Yes             No       123 Shire Lane     None
# 1              No            Yes  93 West Main Street     None
# 2               N            NaN   298 Drugs Driveway     None
# 3             Yes              Y     980 Paper Avenue    18503
# 4               Y             No     123 Dragons Road     None

# %%
#shortening the yes to y and the no to n in both the paying customer column and the do not contact column
df2['paying customer'] = df2['paying customer'].str.replace('Yes', 'Y').str.replace('No', 'N')
df2['do_not_contact'] = df2['do_not_contact'].str.replace('Yes', 'Y').str.replace('No', 'N')

# %%
df2.head()
# Out:
#    customerid first_name last_name  phone_number        address  \
# 0        1001      Frodo   Baggins  123-545-5421          Shire
# 1        1002       Abed     Nadir  123/643/9775           None
# 2        1003     Walter     White    7066950392           None
# 3        1004     Dwight   Schrute  123-543-2345   Pennsylvania
# 4        1005        Jon      Snow  876|678|3469           None
#
#   paying customer do_not_contact       street address zip_code
# 0               Y              N       123 Shire Lane     None
# 1               N              Y  93 West Main Street     None
# 2               N            NaN   298 Drugs Driveway     None
# 3               Y              Y     980 Paper Avenue    18503
# 4               Y              N     123 Dragons Road     None

# %%
# removing special characters from the phone number column
df2['phone_number'] = df2['phone_number'].str.replace(r'[-/|]','',regex=True)
#filling the null values with empty strings and replacing the Na
df2['phone_number'] = df2['phone_number'].fillna('').str.replace('Na','')
df2['phone_number']
# Out:
# 0     1235455421
# 1     1236439775
# 2
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17
# 18
# 19    8766783469
# 20    8766783469
# Name: phone_number, dtype: object

# %%
# df2['phone_number'].apply(lambda x: str(x))
df2['phone_number'] = df2['phone_number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[7:],)

# %%
df2.head(10)
# Out:
#    customerid first_name last_name phone_number        address  \
# 0        1001      Frodo   Baggins  123-545-421          Shire
# 1        1002       Abed     Nadir  123-643-775           None
# 2        1003     Walter     White           --           None
# 3        1004     Dwight   Schrute  123-543-345   Pennsylvania
# 4        1005        Jon      Snow  876-678-469           None
# 5        1006        Ron   Swanson  304-762-467           None
# 6        1007       Jeff    Winger           --           None
# 7        1008   Sherlock    Holmes  876-678-469           None
# 8        1009    Gandalf       NaN           --           None
# 9        1010      Peter    Parker  123-545-421       New York
#
#   paying customer do_not_contact       street address zip_code
# 0               Y              N       123 Shire Lane     None
# 1               N              Y  93 West Main Street     None
# 2               N            NaN   298 Drugs Driveway     None
# ...

# %%
df2.isnull().sum()[df2.isnull().sum() >= 1]
# Out:
# last_name          1
# address           14
# do_not_contact     4
# zip_code          20
# dtype: int64

# %%
#for loop to drop those who don't want to be contacted from the dataframe

for x in df2.index:
    if df2.loc[x, 'do_not_contact'] == "Y":
        df2.drop(x, inplace=True)

# %%
df2.head()
# Out:
#    customerid first_name last_name phone_number address paying customer  \
# 0        1001      Frodo   Baggins  123-545-421   Shire               Y
# 2        1003     Walter     White           --    None               N
# 4        1005        Jon      Snow  876-678-469    None               Y
# 6        1007       Jeff    Winger           --    None               N
# 7        1008   Sherlock    Holmes  876-678-469    None               N
#
#   do_not_contact      street address zip_code
# 0              N      123 Shire Lane     None
# 2            NaN  298 Drugs Driveway     None
# 4              N    123 Dragons Road     None
# 6              N   1209 South Street     None
# 7              N       98 Clue Drive     None

# %%
df2['phone_number']=df2['phone_number'].str.replace(r'--', '',regex=True)
df2['phone_number']
# Out:
# 0     123-545-421
# 4     876-678-469
# 7     876-678-469
# 9     123-545-421
# 12    123-543-345
# 13    876-678-469
# 14    304-762-467
# 15    123-545-421
# 16    123-643-775
# 19    876-678-469
# 20    876-678-469
# Name: phone_number, dtype: object

# %%
#for loop to drop the phone numbers with empty space in the dataframe
for x in df2.index:
    if df2.loc[x, 'phone_number'] == '':
        df.drop(x, axis=1, inplace=True)

# %%
df2.head(20)
# Out:
#     customerid first_name    last_name phone_number        address  \
# 0         1001      Frodo      Baggins  123-545-421          Shire
# 4         1005        Jon         Snow  876-678-469           None
# 7         1008   Sherlock       Holmes  876-678-469           None
# 9         1010      Peter       Parker  123-545-421       New York
# 12        1013        Don       Draper  123-543-345           None
# 13        1014     Leslie        Knope  876-678-469           None
# 14        1015       Toby  Flenderson_  304-762-467           None
# 15        1016        Ron      Weasley  123-545-421           None
# 16        1017   Michael         Scott  123-643-775   Pennsylvania
# 19        1020     Anakin    Skywalker  876-678-469       Tatooine
# 20        1020     Anakin    Skywalker  876-678-469       Tatooine
#
#    paying customer do_not_contact        street address zip_code
# 0                Y              N        123 Shire Lane     None
# ...

# %%
df2.dropna(subset=['do_not_contact'], inplace=True)

# %%
df2.head(20)
# Out:
#     customerid first_name    last_name phone_number        address  \
# 0         1001      Frodo      Baggins  123-545-421          Shire
# 4         1005        Jon         Snow  876-678-469           None
# 7         1008   Sherlock       Holmes  876-678-469           None
# 9         1010      Peter       Parker  123-545-421       New York
# 12        1013        Don       Draper  123-543-345           None
# 13        1014     Leslie        Knope  876-678-469           None
# 14        1015       Toby  Flenderson_  304-762-467           None
# 15        1016        Ron      Weasley  123-545-421           None
# 16        1017   Michael         Scott  123-643-775   Pennsylvania
# 19        1020     Anakin    Skywalker  876-678-469       Tatooine
# 20        1020     Anakin    Skywalker  876-678-469       Tatooine
#
#    paying customer do_not_contact        street address zip_code
# 0                Y              N        123 Shire Lane     None
# ...

# %%
# checking the dataframe, the index is very inconsistent; there's need to reset the index
df2.head(21)
# Out:
#     customerid first_name    last_name phone_number        address  \
# 0         1001      Frodo      Baggins  123-545-421          Shire
# 4         1005        Jon         Snow  876-678-469           None
# 7         1008   Sherlock       Holmes  876-678-469           None
# 9         1010      Peter       Parker  123-545-421       New York
# 12        1013        Don       Draper  123-543-345           None
# 13        1014     Leslie        Knope  876-678-469           None
# 14        1015       Toby  Flenderson_  304-762-467           None
# 15        1016        Ron      Weasley  123-545-421           None
# 16        1017   Michael         Scott  123-643-775   Pennsylvania
# 19        1020     Anakin    Skywalker  876-678-469       Tatooine
# 20        1020     Anakin    Skywalker  876-678-469       Tatooine
#
#    paying customer do_not_contact        street address zip_code
# 0                Y              N        123 Shire Lane     None
# ...

# %%
#resetting the index
df2.reset_index(drop=True,inplace=True)

# %%
df2.head(21)
# Out:
#     customerid first_name    last_name phone_number        address  \
# 0         1001      Frodo      Baggins  123-545-421          Shire
# 1         1005        Jon         Snow  876-678-469           None
# 2         1008   Sherlock       Holmes  876-678-469           None
# 3         1010      Peter       Parker  123-545-421       New York
# 4         1013        Don       Draper  123-543-345           None
# 5         1014     Leslie        Knope  876-678-469           None
# 6         1015       Toby  Flenderson_  304-762-467           None
# 7         1016        Ron      Weasley  123-545-421           None
# 8         1017   Michael         Scott  123-643-775   Pennsylvania
# 9         1020     Anakin    Skywalker  876-678-469       Tatooine
# 10        1020     Anakin    Skywalker  876-678-469       Tatooine
#
#    paying customer do_not_contact        street address zip_code
# 0                Y              N        123 Shire Lane     None
# ...

# %% [markdown]
# ***After the thorough data cleaning, we have only 11 data to hand over to the customer service for them to work with***
